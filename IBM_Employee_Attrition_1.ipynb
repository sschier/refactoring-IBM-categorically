# %%
import numpy as np

import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('/Users/sheenaschier/Documents/Datasets/WA_Fn-UseC_-HR-Employee-Attrition/WA_Fn-UseC_-HR-Employee-Attriti-Table_1.csv')

# %%
print(df.shape)
df.describe()
# Out:
# (1470, 35)
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.hist(figsize=(14,14), xrot=-45)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a160b6240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1695c048>]], dtype=object)

# %%
df[df.Attrition == 'Yes'].hist(figsize=(14,14), xrot=-45)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1eb89278>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1f2f6b00>]], dtype=object)

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
object_filter = df.dtypes == 'object'
for feature in df.dtypes[object_filter].index:
    sns.countplot(y=feature, data=df[df.Age<35], hue='Attrition')
    plt.show()

# %%
sns.countplot(y='OverTime', data=df[df.Attrition == 'Yes'])

# %%
sns.countplot(y='OverTime', data=df[df.Attrition == 'No'])

# %%
sns.countplot(y='OverTime', data=df, hue='Attrition')

# %%
sns.countplot(y='OverTime', data=df[df.Age < 35], hue='Attrition')

# %%
sns.countplot(y='OverTime', data=df[df.Age >= 35], hue='Attrition')

# %%
sns.countplot(y='JobRole', data=df[df.Age < 35], hue='Attrition')

# %%
sns.countplot(y='JobRole', data=df[df.Age >= 35], hue='Attrition')

# %%
sns.violinplot(y='Attrition', x='JobSatisfaction', data=df)

# %%
sns.violinplot(y='YearsInCurrentRole', x='JobSatisfaction', data=df, hue='Attrition')

# %%
sns.violinplot(y='YearsSinceLastPromotion', x='JobSatisfaction', data=df, hue='Attrition')

# %%
sns.violinplot(y='Age', x='JobSatisfaction', data=df, hue='Attrition')

# %%
sns.violinplot(y='Attrition', x='Age', data=df, hue = 'Department')

# %%
sns.violinplot(y='Attrition', x='Age', data=df, hue = 'Gender')

# %%
sns.violinplot(y='Age', x='OverTime', data=df, hue='Attrition')

# %%
sns.violinplot(y='Attrition', x='Age', data=df, hue = 'JobRole', figsize=(100., 30.))

# %%
sns.violinplot(y='Attrition', x='DistanceFromHome', data=df, hue = 'JobRole')

# %%
sns.violinplot(y='JobLevel', x='StockOptionLevel', data=df, hue='Attrition')

# %%
sns.violinplot(y='Attrition', x='WorkLifeBalance', data=df)

# %%
sns.violinplot(y='Attrition', x='PerformanceRating', data=df)

# %%
sns.violinplot(y='Attrition', x='DistanceFromHome', data=df)

# %%
sns.violinplot(y='Attrition', x='YearsSinceLastPromotion', data=df)

# %%
sns.violinplot(y='Attrition', x='Education', data=df)

# %%
sns.violinplot(y='Attrition', x='TotalWorkingYears', data=df)

# %%
sns.violinplot(y='Attrition', x='DailyRate', data=df)

# %%
sns.violinplot(y='Attrition', x='EnvironmentSatisfaction', data=df)

# %%
sns.violinplot(y='Gender', x='HourlyRate', data=df)

# %%
sns.violinplot(y='Gender', x='EnvironmentSatisfaction', data=df)

# %%
sns.violinplot(y='Attrition', x='JobInvolvement', data=df)

# %%
sns.violinplot(y='Gender', x='JobInvolvement', data=df)

# %%
sns.violinplot(y='Attrition', x='JobLevel', data=df)

# %%
sns.violinplot(y='Attrition', x='MonthlyRate', data=df)

# %%
sns.violinplot(y='Attrition', x='MonthlyIncome', data=df)

# %%
sns.violinplot(y='Gender', x='MonthlyIncome', data=df)

# %%
sns.violinplot(y='Attrition', x='StockOptionLevel', data=df)

# %%
sns.violinplot(y='Age', x='StockOptionLevel', data=df, hue='Attrition')

# %%
df.groupby('Attrition').PerformanceRating.agg(['mean', 'std'])
# Out:
#                mean       std
# Attrition
# No         3.153285  0.360408
# Yes        3.156118  0.363735

# %%
sns.lmplot(y='Age', x='DistanceFromHome', hue='Attrition', data=df, fit_reg=False)

# %%
sns.lmplot(y='Age', x='DistanceFromHome', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='Age', x='MonthlyIncome', hue='Attrition', data=df, fit_reg=False)

# %%
sns.lmplot(y='Age', x='MonthlyIncome', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='DistanceFromHome', x='MonthlyIncome', hue='Attrition', data=df, fit_reg=False)

# %%
sns.lmplot(y='DistanceFromHome', x='YearsSinceLastPromotion', hue='Attrition', data=df, fit_reg=False)

# %%
sns.lmplot(y='Age', x='YearsSinceLastPromotion', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='Age', x='YearsSinceLastPromotion', data=df[df.Attrition == 'No'], fit_reg=False)

# %%
sns.lmplot(y='EnvironmentSatisfaction', x='YearsSinceLastPromotion', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='EnvironmentSatisfaction', x='YearsSinceLastPromotion', data=df[df.Attrition == 'No'], fit_reg=False)

# %%
sns.lmplot(y='EnvironmentSatisfaction', x='Age', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='YearsSinceLastPromotion', x='JobSatisfaction', data=df[df.Attrition == 'Yes'])

# %%
sns.lmplot(y='YearsSinceLastPromotion', x='WorkLifeBalance', data=df[df.Attrition == 'Yes'], fit_reg=False)

# %%
sns.lmplot(y='YearsSinceLastPromotion', x='PerformanceRating', data=df[df.Attrition == 'Yes'])

# %%
sns.violinplot(y='YearsSinceLastPromotion', x='PerformanceRating', data=df, hue = 'Attrition')

# %%
sns.violinplot(y='TrainingTimesLastYear', x='PerformanceRating', data=df, hue = 'Attrition')

# %%
sns.violinplot(y='TrainingTimesLastYear', x='PercentSalaryHike', data=df, hue = 'Attrition')

# %%
sns.lmplot(y='TrainingTimesLastYear', x='PercentSalaryHike', data=df[df.Attrition == 'Yes'])

# %% [markdown]
# ### Should start adding new features

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df['Young'] = (df.Age<35).astype(int)

# %%
df.Young.hist()

# %%
df[df.Attrition == 'Yes'].Young.hist()

# %%
df[df.Attrition == 'No'].Young.hist()

# %%
df['OverWorkedUnderPaid'] = ((df.OverTime == 'Yes') & (df.MonthlyIncome < 10000.)).astype(int)

# %%
df.OverWorkedUnderPaid.hist()

# %%
df[df.Attrition == 'Yes'].OverWorkedUnderPaid.hist()

# %%
df[df.Attrition == 'No'].OverWorkedUnderPaid.hist()

# %%
df['UnderAppreciated'] = ((df.JobLevel<2.) & (df.StockOptionLevel < 2.)).astype(int)

# %%
df.UnderAppreciated.hist()

# %%
df[df.Attrition == 'Yes'].UnderAppreciated.hist()

# %%
sns.violinplot(y='Attrition', x='EnvironmentSatisfaction', data=df[df.JobSatisfaction <3])

# %%
sns.violinplot(y='Attrition', x='EnvironmentSatisfaction', data=df[df.JobSatisfaction >3])

# %%
df['Unhappy'] = ((df.JobSatisfaction < 4) & (df.EnvironmentSatisfaction < 4))

# %%
df.Unhappy.hist()

# %%
df[df.Attrition == 'Yes'].Unhappy.hist()

# %%
df[df.Attrition == 'No'].Unhappy.hist()

# %% [markdown]
# #### Added three features
# 1) Young
# 2) Underappreciated
# 3) Unhappy

# %% [markdown]
# Need to change all categorical variables to indicator variables

# %%
df.Attrition = pd.get_dummies(df.Attrition).Yes

# %%
df.Attrition.mean()
# Out:
# 0.16122448979591836

# %%
df = df.drop_duplicates()
df.describe(include = 'object')
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1470                    1470           1470   1470
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df = df.drop(columns = ['Over18'])

# %%
df.describe(include = 'object')
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1470                    1470           1470   1470
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1043                     961            606    882
#
#                 JobRole MaritalStatus OverTime
# count              1470          1470     1470
# unique                9             3        2
# top     Sales Executive       Married       No
# freq                326           673     1054

# %%
df_final = pd.get_dummies(df, columns=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime'])

# %%
df_final.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %% [markdown]
# ### Save new dataframe

# %%
df_final.to_csv('cleaned_IBM_attrition_df.csv', index=False)
